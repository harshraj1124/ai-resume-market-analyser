# %% [markdown]
# # AI Resume Market Analyzer EDA
#
# This notebook runs the end-to-end synthetic data and analysis workflow, then inspects supply-demand gaps for India-focused recruiting strategy.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT))

from src.data_generator import GeneratorConfig, generate_all
from main_pipeline import run_pipeline

generate_all(GeneratorConfig(resumes=1500, jobs=800, output_dir=ROOT / 'data' / 'synthetic'))
run_pipeline()

# %%
import pandas as pd

gap = pd.read_parquet(ROOT / 'data' / 'processed' / 'skill_gap.parquet')
recommendations = pd.read_parquet(ROOT / 'data' / 'processed' / 'recommendations.parquet')
gap.head(15)

# %% [markdown]
# The highest positive gap scores indicate demand that materially exceeds available resume supply. Recruiting teams should prioritize these skills for sourcing campaigns, compensation reviews, and city-specific talent mapping.

# %%
recommendations.head(10)
